# %%
import pandas as pd

partido_df = pd.read_csv('Ano-2020.csv', delimiter=';')
partido_df.dtypes
df = partido_df[partido_df['txtDescricao'] == 'DIVULGAÇÃO DA ATIVIDADE PARLAMENTAR.']
# df[df['vlrDocumento'] > 90000]
df.boxplot(column='vlrDocumento', by='sgPartido', grid=False)
# Out:
# <AxesSubplot:title={'center':'vlrDocumento'}, xlabel='sgPartido'>
